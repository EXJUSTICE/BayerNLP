# %%
import sys
import datetime as dt
import pandas as pd
pd.set_option("display.max_rows",500)
pd.set_option("display.max_columns",500)
# Out:
# /home/yijie/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %% [markdown]
# # Bayer NLP task - Baseline NGRAM evaluation
# This notebook follows previous EDA notebook, working to evaluate the utility of NGRAM approaches for baseline LGBM model.
# This is done prior to moving one to alternative models
# (c) Yijie Xu

# %%
sys.path.insert(0, '..') # Set root directory
sys.path.insert(0, '/home/yijie/Documents/Bayer/BayerNLP/scripts')# Set root directory

# %%
sys.path
# Out:
# ['/home/yijie/Documents/Bayer/BayerNLP/scripts',
#  '..',
#  '/home/yijie/Documents/Bayer/BayerNLP/notebooks',
#  '/home/yijie/anaconda3/lib/python38.zip',
#  '/home/yijie/anaconda3/lib/python3.8',
#  '/home/yijie/anaconda3/lib/python3.8/lib-dynload',
#  '',
#  '/home/yijie/anaconda3/lib/python3.8/site-packages']

# %%
data =pd.read_csv("../data/sentences_with_sentiment.csv",sep=",")

# %%
data
# Out:
#       ID                                           Sentence  Positive  \
# 0      1  The results in 2nd line treatment show an ORR ...         1
# 1      2  The long duration of response and high durable...         1
# 2      3  The median OS time in the updated results exce...         0
# 3      4  Therefore, the clinical benefit in 2nd line tr...         1
# 4      5  The data provided in 1st line, although prelim...         1
# 5      6  Taking into account the intrinsic limitation o...         1
# 6      7  This medicinal product has been authorised und...         0
# 7      8  This means that further evidence on this medic...         0
# 8      9  The European Medicines Agency will review new ...         0
# 9     10  The CHMP considers the following measures nece...         0
# 10    11  In order to confirm the efficacy for chemother...         0
# 11    12  The final results of the study should be submi...         0
# ...

# %% [markdown]
# # Data Inspection and Analysis
# Research Questions
#
# • Is the dataset balanced?
#
# • Is the amount of data sufficient for allowing a hold-out dataset?
#
# • Do you have enough data to consider deep neural architectures or
# might good feature engineering with more shallow models suffice?
#
# • During the data collection process, for some sentences multiple experts
# disagreed on the sentiment of a given sentence, how could you capture
# such an ambiguity in your model and potentially notify users about
# such unclear instances?
#
# • How does your model come to a specific conclusion, what about model
# interpretability?
#
# • Think beyond the pure sentiment analysis of sentences, e.g. how would
# you automatically extract relevant sentences from EPARs and ensure
# that the analysis is only applied to specific sections? It is worth to
# explore some EPARs on the EMA we

# %%
print(len(data)) # 266 Rows of data
# Out:
# 266

# %%
#Classes
data["Positive"].value_counts()
# Out:
# 1    160
# 0    106
# Name: Positive, dtype: int64

# %%
data['Negative'].value_counts()
# Out:
# 0    230
# 1     36
# Name: Negative, dtype: int64

# %%
data['Neutral'].value_counts()
# Out:
# 0    196
# 1     70
# Name: Neutral, dtype: int64

# %%
pos=data["Positive"].value_counts()[1]
neg=data["Negative"].value_counts()[1]
neu= data["Neutral"].value_counts()[1]

# %%
#Check that no overlap occurs per row by summing in across columns

data["check"] =data[["Neutral","Negative","Positive"]].sum(axis=1)
data.head()
# Out:
#    ID                                           Sentence  Positive  Negative  \
# 0   1  The results in 2nd line treatment show an ORR ...         1         0
# 1   2  The long duration of response and high durable...         1         0
# 2   3  The median OS time in the updated results exce...         0         0
# 3   4  Therefore, the clinical benefit in 2nd line tr...         1         0
# 4   5  The data provided in 1st line, although prelim...         1         0
#
#    Neutral  check
# 0        0      1
# 1        0      1
# 2        1      1
# 3        0      1
# 4        0      1

# %% [markdown]
# # Data Cleaning and Processing
# Perform a Null check and proceed with statistical features and other cleaning.
# Some basic NLP processes, such as stemming and polarity, also done.

# %%
data.isnull().values.any()
# Out:
# False

# %%
#Lets combine all of the sentiments into a single polarity feature 
# Three classes here, 1,0, -1
def convert_sentiment(row):
    if row['Positive'] == 1:
        val = 1
    elif row['Negative'] ==1:
        val=-1
    else:
        val=0
    return val

# %%
data["sentiment"]=data.apply(lambda row: convert_sentiment(row), axis=1)

# %%
data.head()
# Out:
#    ID                                           Sentence  Positive  Negative  \
# 0   1  The results in 2nd line treatment show an ORR ...         1         0
# 1   2  The long duration of response and high durable...         1         0
# 2   3  The median OS time in the updated results exce...         0         0
# 3   4  Therefore, the clinical benefit in 2nd line tr...         1         0
# 4   5  The data provided in 1st line, although prelim...         1         0
#
#    Neutral  check  sentiment
# 0        0      1          1
# 1        0      1          1
# 2        1      1          0
# 3        0      1          1
# 4        0      1          1

# %%
#Data cleaning and standardization
from utils import processing
# Out:
# [nltk_data] Downloading package stopwords to /home/yijie/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
data_processed = processing(data)

# %% [markdown]
# # Baseline with NGRAMS
# Our first baseline is  a basic lightGBM attempt, using our statistical features and vectorized features.
# LGBM is a gradient boosted tree method that is light, fast, and flexible.
# Results obtained with hyperparameter tuning GridSearchCV. Oversampling performed with SVMSMOTE
#
# Note for scoring, we utilize balanced acc and f1 to better handle the class imbalance
# #https://medium.com/analytics-vidhya/accuracy-vs-f1-score-6258237beca2

# %%
# Importing Libraries for the Machine Learning Model
from xgboost import XGBClassifier
from lightgbm import LGBMModel,LGBMClassifier, plot_importance
from sklearn.metrics import confusion_matrix, accuracy_score,balanced_accuracy_score, f1_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold, StratifiedKFold, RepeatedStratifiedKFold
from sklearn.model_selection import cross_val_score, cross_val_predict, GridSearchCV
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.feature_extraction.text import CountVectorizer
from imblearn.over_sampling import SMOTE, ADASYN, BorderlineSMOTE, SVMSMOTE, RandomOverSampler
from scipy import sparse

# %%
NGRAM_Target = 'clean_stem'
features = data[[NGRAM_Target,'polarity_clean','polarity','polarity_clean_stem',  'count_word', 'count_unique_word', 'count_letters',
                   'count_punctuations', 'count_words_upper', 'count_words_title',
                   'count_stopwords', 'mean_word_len']]

target = data['sentiment']

# %%
#Perform NGRAM Modelling

vect = CountVectorizer(ngram_range=(1,3)).fit(features[NGRAM_Target]) #NGram range just refers to the max consecutive words to make an engram of


feature_names = vect.get_feature_names()
#Fetch the respective train and test data and select just the relevant Sentence column, Implement vectorization

vect_X =  vect.transform(features[NGRAM_Target])
features= features.drop(columns=[NGRAM_Target])
#Combine vectorized data with original data, minus the originalsentence

# %%
print(type(vect_X))
# Out:
# <class 'scipy.sparse._csr.csr_matrix'>

# %%
print(vect_X.get_shape())
# Out:
# (266, 6681)

# %%
from sklearn.decomposition import TruncatedSVD
from sklearn.manifold import TSNE
truncate= "tsne"
if truncate =="svd":
    svdT = TruncatedSVD(n_components=3000)
    svdTFit = svdT.fit_transform(vect_X)
    svddf = pd.DataFrame(svdTFit)
    X_vect= features.join(svddf)
elif truncate =="tsne":
    model = TSNE(n_components=1000, random_state=0,perplexity=30, method='exact')
    tsne_data = model.fit_transform(vect_X)
    tsnedf = pd.DataFrame(tsne_data)
    X_vect= features.join(tsnedf)
else:
    X_vect = sparse.hstack([vect_X, features])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 11
#       9 elif truncate =="tsne":
#      10     model = TSNE(n_components=1000, random_state=0,perplexity=30, method='exact')
# ---> 11     tsne_data = model.fit_transform(vect_X)
#      12     tsnedf = pd.DataFrame(tsne_data)
#      13     X_vect= features.join(tsnedf)
#
# File ~/anaconda3/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:1123, in TSNE.fit_transform(self, X, y)
#    1103 """Fit X into an embedded space and return that transformed output.
#    1104
#    1105 Parameters
#    (...)
#    1120     Embedding of the training data in low-dimensional space.
#    1121 """
#    1122 self._check_params_vs_input(X)
# -> 1123 embedding = self._fit(X)
#    1124 self.embedding_ = embedding
#    1125 return self.embedding_
#
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X_vect, target, test_size = 0.2, random_state = 42,stratify=target)
print ("The Train set size ", X_train.shape)
print ("The Test set size ", X_test.shape)

# %%
# Introducing oversampling
oversampling=True
if oversampling == True:
    ADAsm = SVMSMOTE(random_state=100)
    X_train_smote, y_train_smote= ADAsm.fit_resample(X_train, y_train)
    X_train_orig = X_train.copy()
    y_train_orig = y_train.copy()
    
    X_train = X_train_smote.copy()
    y_train = y_train_smote.copy()

# %%
#Tune hyperparameters
from utils import hyperparam_tune        
    

params = {
        'learning_rate': [0.01,0.05, 0.1, 0.3,0.5],
        'max_depth' : [-1,5,10,20],
        'num_leaves' : [2,5,10,20,31],
        'colsample_bytree' :  [0.1,0.5,1],
        'n_estimators':  [25,50,100,150,200,]
    }

# %%
best,acc,acc_b,f1,rep,clfr = hyperparam_tune("lgbm",params,X_train,y_train,X_test,y_test)

# %%
best

# %%
acc

# %%
acc_b

# %%
f1

# %%
print(rep)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
predictions = clfr.predict(X_test)
cm=confusion_matrix(y_test, predictions)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=clfr.classes_)
disp.plot()
plt.tick_params(axis=u'both', which=u'both',length=0)
plt.grid(False)
plt.show()

#Visualize Confusion Matrix

# %%
plt.rcParams['figure.figsize'] = [12, 9]
sns.set(style = 'darkgrid', font_scale = 1.2)
plot_importance(clfr.best_estimator_,  max_num_features=13)

# %%
len(vect.get_feature_names())

# %%
#Let's replace the column vector names with their actual text entries

vect.get_feature_names()[1403]
